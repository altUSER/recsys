# %%
# !pip install pandas matplotlib seaborn scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
def truncate_column_name(name, max_length=10):
    """
    Обрезает название столбца до максимальной длины
    """
    if len(str(name)) <= max_length:
        return str(name)
    return str(name)[:max_length-3] + "..."

def plot_boxplots(df):
    """
    Выводит boxplot для всех численных столбцов в DataFrame
    """
    # Выбираем только численные колонки
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    
    if len(numeric_columns) == 0:
        print("В DataFrame нет численных столбцов")
        return
    
    # Определяем количество строк и столбцов для subplot
    n_cols = 3
    n_rows = (len(numeric_columns) + n_cols - 1) // n_cols
    
    # Создаем grid subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
    
    # Преобразуем axes в плоский массив для единообразной обработки
    if n_rows == 1 and n_cols == 1:
        axes = np.array([axes])
    elif n_rows == 1 or n_cols == 1:
        axes = axes.flat
    else:
        axes = axes.flatten()
    
    # Строим boxplot для каждого численного столбца
    for i, col in enumerate(numeric_columns):
        if i < len(axes):
            axes[i].boxplot(df[col].dropna())
            truncated_name = truncate_column_name(col)
            axes[i].set_title(f'Boxplot: {truncated_name}')
            axes[i].set_ylabel('Values')
    
    # Убираем лишние subplots
    for i in range(len(numeric_columns), len(axes)):
        axes[i].set_visible(False)
    
    plt.tight_layout()
    plt.show()

def plot_histograms(df):
    """
    Выводит гистограммы для всех столбцов (включая нечисловые)
    """
    # Все колонки
    all_columns = df.columns
    
    if len(all_columns) == 0:
        print("DataFrame пустой")
        return
    
    # Определяем количество строк и столбцов для subplot
    n_cols = 3
    n_rows = (len(all_columns) + n_cols - 1) // n_cols
    
    # Создаем grid subplots
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5*n_rows))
    
    # Преобразуем axes в плоский массив для единообразной обработки
    if n_rows == 1 and n_cols == 1:
        axes = np.array([axes])
    elif n_rows == 1 or n_cols == 1:
        axes = axes.flat
    else:
        axes = axes.flatten()
    
    # Строим гистограммы для каждого столбца
    for i, col in enumerate(all_columns):
        if i < len(axes):
            truncated_name = truncate_column_name(col)
            
            # Для числовых данных
            if pd.api.types.is_numeric_dtype(df[col]):
                axes[i].hist(df[col].dropna(), bins=30, alpha=0.7, edgecolor='black')
                axes[i].set_title(f'Histogram: {truncated_name}')
                axes[i].set_xlabel('Values')
                axes[i].set_ylabel('Frequency')
            # Для категориальных данных
            else:
                value_counts = df[col].value_counts().head(10)  # Берем топ-10 значений
                
                # Обрезаем имена категорий для подписей на оси X
                truncated_labels = [truncate_column_name(str(label)) for label in value_counts.index]
                
                axes[i].bar(range(len(truncated_labels)), value_counts.values)
                axes[i].set_title(f'Bar chart: {truncated_name}')
                axes[i].set_xlabel('Categories')
                axes[i].set_ylabel('Count')
                axes[i].set_xticks(range(len(truncated_labels)))
                axes[i].set_xticklabels(truncated_labels, rotation=45, ha='right')
    
    # Убираем лишние subplots
    for i in range(len(all_columns), len(axes)):
        axes[i].set_visible(False)
    
    plt.tight_layout()
    plt.show()

def create_cluster_model(df, n_clusters=3, random_state=42):
    """
    Создает модель кластеризации и визуализирует результат в 2D
    """
    # Выбираем только численные колонки и удаляем пропуски
    numeric_df = df.select_dtypes(include=[np.number]).dropna()
    
    if len(numeric_df) == 0:
        print("Нет данных для кластеризации")
        return None, None
    
    if len(numeric_df) < n_clusters:
        print(f"Недостаточно данных для {n_clusters} кластеров")
        return None, None
    
    # Стандартизируем данные
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(numeric_df)
    
    # Создаем модель кластеризации K-means
    kmeans = KMeans(n_clusters=n_clusters, random_state=random_state, n_init=10)
    clusters = kmeans.fit_predict(scaled_data)
    
    # Уменьшаем размерность до 2D с помощью PCA
    pca = PCA(n_components=2)
    reduced_data = pca.fit_transform(scaled_data)
    
    # Создаем график
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(reduced_data[:, 0], reduced_data[:, 1], 
                         c=clusters, cmap='viridis', alpha=0.6)
    plt.colorbar(scatter, label='Cluster')
    plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
    plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
    plt.title(f'K-means Clustering (n_clusters={n_clusters})')
    plt.grid(True, alpha=0.3)
    
    # Добавляем центроиды кластеров
    centroids = pca.transform(kmeans.cluster_centers_)
    plt.scatter(centroids[:, 0], centroids[:, 1], 
               marker='X', s=200, c='red', label='Centroids')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Выводим информацию о кластерах
    cluster_info = pd.DataFrame({
        'cluster': range(n_clusters),
        'size': [sum(clusters == i) for i in range(n_clusters)]
    })
    print("Информация о кластерах:")
    print(cluster_info)
    
    return kmeans, pca

# %%
df_items = pd.read_csv("./data_en/items_en.csv")
df_items = df_items.drop('Unnamed: 0', axis=1)
df_items.head()
# Out:
#    item_id content_type                          title      title_orig  \
# 0    10711         film                    Talk to her  Hable con ella
# 1     2508         film                  Naked Peppers    Search Party
# 2    10716         film                 Tactical force  Tactical Force
# 3     7868         film                   45 years old        45 Years
# 4    16268         film  Everything Solves in a Moment             NaN
#
#    release_year                                     genres countries  \
# 0        2002.0       drama, foreign, detective, melodrama     Spain
# 1        2014.0                 foreign, adventure, comedy       USA
# 2        2011.0  crime, foreign, thrillers, action, comedy    Canada
# 3        2015.0                  drama, foreign, melodrama        UK
# 4        1978.0            drama, sport, soviet, melodrama      USSR
#
#    for_kids  age_rating  studios  \
# 0       NaN        16.0      NaN
# 1       NaN        16.0      NaN
# 2       NaN        16.0      NaN
# 3       NaN        16.0      NaN
# 4       NaN        12.0  Lenfilm
#
#                                          description  \
# 0  Marco, a journalist, interviews the famous Tor...
# 1  The main character has learned not to invite h...
# 2  Professional wrestler Steve Austin ("All or No...
# 3  Charlotte Rampling, Tom Courtney, Geraldine Ja...
# 4  The circle of her mentors and the most loyal f...
#
#                                             keywords  \
# 0  Talk, her, 2002, Spain, friends, love, strong,...
# 1  Naked, Peppers, 2014, USA, friends, weddings, ...
# 2  Tactical, Force, 2011, Canada, bandits, gangst...
# 3  45, years, 2015, United Kingdom, marriage, lif...
# 4  Everything that decides, moment, 1978, USSR, s...
#
#                                    actors_translated  \
# 0  Adolfo Fernández, Ana Fernández, Dario Grandin...
# 1  Adam Palley, Brian Huskey, JB Smoove, Jason Ma...
# 2  Adrian Holmes, Darren Shalavi, Jerry Wasserman...
# 3  Alexandra Riddleston-Barrett, Geraldine James,...
# 4  Aleksandr Abdulov, Aleksandr Demyanenko, Alexe...
#
#                                actors_transliterated directors_translated  \
# 0  Adol'fo Fernandes, Ana Fernandes, Dario Grandi...      Pedro Almodovar
# 1  Adam Palli, Brajan Haski, Dzh.B. Smuv, Dzhejso...      Scott Armstrong
# 2  Adrian Holms, Darren Shalavi, Dzherri Vasserma...     Adam P. Caltraro
# 3  Aleksandra Riddlston-Barrett, Dzheral'din Dzhe...        By Andrew Hay
# 4  Aleksandr Abdulov, Aleksandr Dem'janenko, Alek...      Victor Sadovsky
#
#      transliterated
# 0  Pedro Al'modovar
# 1    Skot Armstrong
# 2  Adam P. Kaltraro
# 3        Endrju Hej
# 4  Viktor Sadovskij

# %%
df_users = pd.read_csv("./data_en/users_en.csv")
df_users = df_users.drop('Unnamed: 0', axis=1)
df_users.head()
# Out:
#    user_id        age        income sex  kids_flg
# 0   973171  age_25_34  income_60_90   M         1
# 1   962099  age_18_24  income_20_40   M         0
# 2  1047345  age_45_54  income_40_60   F         0
# 3   721985  age_45_54  income_20_40   F         0
# 4   704055  age_35_44  income_60_90   F         0

# %%
df_interactions = pd.read_csv("./data_en/interactions.csv")
df_interactions = df_interactions[int(len(df_interactions)*-0.5):]
df_interactions['last_watch_dt'] = pd.to_datetime(df_interactions['last_watch_dt'])
df_interactions.head()
# Out:
#          user_id  item_id last_watch_dt  total_dur  watched_pct
# 2738126   674763    13865    2021-08-10          1          0.0
# 2738127    34088     1399    2021-08-21        530          7.0
# 2738128   644277     9728    2021-07-09          9          0.0
# 2738129   709231     9103    2021-08-17       4075         75.0
# 2738130   449017    15651    2021-05-09         19          0.0

# %%
def new_metric(recommended_list, watched_list):
    rec = np.array(recommended_list)
    wat = np.array(watched_list)
    inter = wat - rec 
    inter = np.abs(inter)
    return inter.sum() / len(inter)

# %%
df_items['genres_parsed'] = df_items['genres'].apply(lambda x: list(str(x).split(',')))
df_items['keywords_parsed'] = df_items['keywords'].apply(lambda x: list(str(x).split(',')))
df_items['actors_translated_parsed'] = df_items['actors_translated'].apply(lambda x: list(str(x).split(',')))
df_items['directors_translated_parsed'] = df_items['directors_translated'].apply(lambda x: list(str(x).split(',')))

# %%
test_size_weeks = 3
df_interactions_test = df_interactions[df_interactions['last_watch_dt'].max() - df_interactions['last_watch_dt'] < np.timedelta64(21) ]
df_interactions_train = df_interactions[df_interactions['last_watch_dt'].max() - df_interactions['last_watch_dt'] >= np.timedelta64(21) ]
df_interactions_test = df_interactions_test.groupby('item_id').filter(lambda group: len(group) > 2)
df_interactions_train = df_interactions_train.groupby('item_id').filter(lambda group: len(group) > 2)
# common_item_ids = df_interactions_test['item_id'].isin(df_interactions_train['item_id'])
# common_item_ids = common_item_ids[common_item_ids].index
# df_interactions_test = df_interactions_test[df_interactions_test['item_id'].isin(common_item_ids)]
# df_interactions_train = df_interactions_train[df_interactions_train['item_id'].isin(common_item_ids)]
print(f"length of df_interactions_test: {len(df_interactions_test)}")
print(f"length of df_interactions_train: {len(df_interactions_train)}")
# Out:
# length of df_interactions_test: 33446
# length of df_interactions_train: 2697212

# %%
# users_with_views = df_interactions_test['user_id'].unique()
users_with_views = df_interactions_test.groupby('user_id').filter(lambda group: len(group) > 2 and len(group) < 20)['user_id'].unique()
all_users = df_users['user_id'].unique()

flags = np.isin(users_with_views, all_users)
users_with_views = users_with_views[flags]

# %%
def precision_at_k(recommended_list, watched_list, k=5):
    
    watched_list = np.array(watched_list)
    recommended_list = np.array(recommended_list)
    
    #assert len(watched_list) > len(recommended_list)
    watched_list = watched_list  # Тут нет [:k] !!
    recommended_list = recommended_list[:k]
    
    flags = np.isin(watched_list, recommended_list)
    
    precision = flags.sum() / len(recommended_list)
    
    
    return precision

def ap_k(recommended_list, watched_list, k=5):
    """
    Вычисляет Average Precision at k (AP@k)

    Parameters:
    recommended_list (list или np.array): Ранжированный список рекомендаций
    watched_list (list или np.array): Список релевантных (просмотренных) элементов
    k (int): Глубина оценки (по умолчанию 5)

    Returns:
    float: Значение AP@k
    """
    # Если recommended_list двумерный (содержит пары [item_id, weight]), 
    # извлекаем только item_id из первого столбца
    recommended_list = np.array(recommended_list)
    if recommended_list.ndim == 2:
        recommended_list = recommended_list[:, 0]  # Берем только item_id
    
    watched_list = np.array(watched_list)
    recommended_list = recommended_list[:k]  # ✅ Ограничиваем k рекомендациями
    
    # Создаем булев массив совпадений
    flags = np.isin(recommended_list, watched_list)
    
    # Если в рекомендациях нет релевантных элементов, возвращаем 0
    relevant_count = np.sum(flags)
    if relevant_count == 0:
        return 0.0
    
    # Вычисляем AP@k
    sum_precision = 0.0
    for i in range(len(recommended_list)):
        if flags[i]:  # ✅ Теперь flags[i] - скалярное булево значение
            # Precision at k вычисляется для текущей глубины i+1
            p_k = np.sum(flags[:i+1]) / (i+1)
            sum_precision += p_k
    
    # Делим на количество релевантных элементов в топ-k
    ap_result = sum_precision / relevant_count
    
    return ap_result

def map_k(recommended_list, watched_list, k=5, u=1):
    sum_ = 0
    l = min(len(watched_list), u)
    for i in range(l):
        sum_ += ap_k(recommended_list[i], watched_list[i], k)
    result = sum_ / l
    return result

# %%
def progress_bar(current, total, bar_length=50, append=""):
    fraction = current / total
    arrow = int(fraction * bar_length - 1) * '=' + '>'
    padding = (bar_length - len(arrow)) * ' '
    
    progress = f'Progress: [{arrow}{padding}] {int(fraction*100)}%\t{current}/{total}' + append
    print(progress, end='\r')
    
    if current == total: 
        print()

# %%
def count_avg_MAP_for_recommendation(users_with_views, df_interactions_train, df_interactions_test, df_items, recommend_func, coefs=[0.5,0.5,0.5]):
    map_10 = 0
    l = len(users_with_views)
    for i, user in enumerate(users_with_views):
        progress_bar(i, l)
        watched_previous_list = df_interactions_train[df_interactions_train["user_id"] == user]
        user_info = df_users[df_users['user_id'] == user]
        items = df_items
        recomendations = recommend_func(user_info, watched_previous_list, df_interactions_train, items, count = 10, coefs=coefs)
        map_10 += ap_k(recomendations, df_interactions_test[df_interactions_test['user_id'] == user]['item_id'])

    map_10 /= len(users_with_views)
    return map_10

def stand(users_with_views, df_interactions_train, df_interactions_test, df_items, recommend_func, *args, **kwargs):
    map_10 = 0
    l = len(users_with_views)
    user = users_with_views[0]
    print("\ndf_interactions_train")
    print(df_interactions_train)
    watched_previous_list = df_interactions_train[df_interactions_train["user_id"] == user]
    print("\nwatched_previous_list")
    print(watched_previous_list)
    user_info = df_users[df_users['user_id'] == user]
    print("\nuser_info")
    print(user_info)
    items = df_items
    print("\nitems")
    print(items)
    # recomendations = recommend_func(user_info, watched_previous_list, df_interactions_train, items, count = 10)
    # map_10 += ap_k(recomendations, df_interactions_test[df_interactions_test['user_id'] == user]['item_id'])

    # map_10 /= len(users_with_views)
    # return map_10

# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

class ALS:
    def __init__(self, n_factors=10, alpha=40, regularization=0.1, iterations=15):
        """
        Инициализация ALS модели
        
        Parameters:
        - n_factors: количество латентных факторов
        - alpha: параметр уверенности для неявной обратной связи
        - regularization: коэффициент регуляризации (lambda)
        - iterations: количество итераций обучения
        """
        self.n_factors = n_factors
        self.alpha = alpha
        self.regularization = regularization
        self.iterations = iterations
        self.user_factors = None
        self.item_factors = None
        self.loss_history = []
    
    def fit(self, ratings):
        """
        Обучение ALS модели
        
        Parameters:
        - ratings: scipy sparse matrix в формате (users × items)
        """
        n_users, n_items = ratings.shape
        
        # Инициализация матриц факторов
        self.user_factors = np.random.normal(0, 0.1, (n_users, self.n_factors))
        self.item_factors = np.random.normal(0, 0.1, (n_items, self.n_factors))
        
        print("Начинаем обучение ALS...")
        
        for iteration in range(self.iterations):
            # Шаг 1: Фиксируем item factors, обновляем user factors
            for u in range(n_users):
                # Получаем индексы и значения оценок пользователя
                user_ratings = ratings[u].toarray().flatten()
                rated_items = np.where(user_ratings > 0)[0]
                
                if len(rated_items) > 0:
                    # Вычисляем уверенности для неявной обратной связи
                    confidence = 1 + self.alpha * user_ratings[rated_items]
                    
                    # Матрица item factors для оцененных items
                    Y = self.item_factors[rated_items]
                    
                    # Вычисляем матрицу A и вектор b
                    C = np.diag(confidence)
                    A = Y.T @ C @ Y + self.regularization * np.eye(self.n_factors)
                    b = Y.T @ confidence
                    
                    # Решаем линейную систему
                    self.user_factors[u] = np.linalg.solve(A, b)
            
            # Шаг 2: Фиксируем user factors, обновляем item factors
            for i in range(n_items):
                # Получаем индексы и значения оценок для item
                item_ratings = ratings[:, i].toarray().flatten()
                rating_users = np.where(item_ratings > 0)[0]
                
                if len(rating_users) > 0:
                    # Вычисляем уверенности
                    confidence = 1 + self.alpha * item_ratings[rating_users]
                    
                    # Матрица user factors для оценивших пользователей
                    X = self.user_factors[rating_users]
                    
                    # Вычисляем матрицу A и вектор b
                    C = np.diag(confidence)
                    A = X.T @ C @ X + self.regularization * np.eye(self.n_factors)
                    b = X.T @ confidence
                    
                    # Решаем линейную систему
                    self.item_factors[i] = np.linalg.solve(A, b)
            
            # Вычисляем loss
            loss = self._compute_loss(ratings)
            self.loss_history.append(loss)
            print(f"Итерация {iteration + 1}/{self.iterations}, Loss: {loss:.4f}")
    
    def _compute_loss(self, ratings):
        """Вычисление функции потерь"""
        loss = 0
        n_users, n_items = ratings.shape
        
        for u in range(n_users):
            for i in range(n_items):
                if ratings[u, i] > 0:
                    prediction = self.user_factors[u] @ self.item_factors[i]
                    confidence = 1 + self.alpha * ratings[u, i]
                    error = confidence - prediction
                    loss += error ** 2
        
        # Добавляем регуляризацию
        reg_loss = self.regularization * (
            np.sum(self.user_factors ** 2) + np.sum(self.item_factors ** 2)
        )
        
        return loss + reg_loss
    
    def predict(self, user_id, item_id):
        """Предсказание оценки"""
        return self.user_factors[user_id] @ self.item_factors[item_id]
    
    def recommend(self, user_id, n_recommendations=10):
        """Рекомендации для пользователя"""
        user_vector = self.user_factors[user_id]
        scores = user_vector @ self.item_factors.T
        top_items = np.argsort(scores)[::-1][:n_recommendations]
        return top_items, scores[top_items]
    
    def plot_loss(self):
        """Визуализация истории потерь"""
        plt.figure(figsize=(10, 6))
        plt.plot(self.loss_history, marker='o')
        plt.title('История обучения ALS')
        plt.xlabel('Итерация')
        plt.ylabel('Loss')
        plt.grid(True)
        plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
import scipy.sparse as sp
def create_sparse_interaction_matrix(users_with_views, df_interactions_train, df_items):
    """
    Создает разреженную матрицу взаимодействий пользователь-предмет
    
    Parameters:
    -----------
    users_with_views : list
        Список пользователей для включения в матрицу
    df_interactions_train : pd.DataFrame
        Тренировочные взаимодействия со столбцами ['user_id', 'item_id', 'watched_pct']
    df_items : pd.DataFrame
        Список всех предметов
    
    Returns:
    --------
    sparse_matrix : scipy.sparse.csr_matrix
        Разреженная матрица взаимодействий
    user_encoder : LabelEncoder
        Кодировщик user_id в индексы строк
    item_encoder : LabelEncoder  
        Кодировщик item_id в индексы столбцов
    """
    
    # Фильтруем взаимодействия только для нужных пользователей
    filtered_interactions = df_interactions_train[
        df_interactions_train['user_id'].isin(users_with_views)
    ].copy()
    
    # Создаем кодировщики для пользователей и предметов
    user_encoder = LabelEncoder()
    item_encoder = LabelEncoder()
    
    # Подготавливаем всех возможных пользователей и предметы
    all_users = sorted(users_with_views)
    all_items = sorted(df_items['item_id'].unique())
    
    # Обучаем кодировщики
    user_encoder.fit(all_users)
    item_encoder.fit(all_items)
    
    # Преобразуем user_id и item_id в числовые индексы
    user_indices = user_encoder.transform(filtered_interactions['user_id'])
    item_indices = item_encoder.transform(filtered_interactions['item_id'])
    
    def vals(vs):
        return vs/100 if vs>50 else 0
    # Вычисляем значения watched_pct / 100
    values = filtered_interactions['watched_pct'].apply(vals)
    
    # Создаем разреженную матрицу в формате COO
    sparse_matrix = sp.coo_matrix(
        (values, (user_indices, item_indices)),
        shape=(len(all_users), len(all_items))
    )
    
    # Конвертируем в CSR для эффективных операций
    sparse_matrix_csr = sparse_matrix.tocsr()
    
    return sparse_matrix_csr, user_encoder, item_encoder

# %%
sparse_matrix_csr, user_encoder, item_encoder = create_sparse_interaction_matrix(users_with_views, df_interactions_train[int(len(df_interactions_train)*-0.5):], df_items)
sparse_matrix_csr
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 7450 stored elements and shape (1307, 15963)>

# %%
als_model = ALS(
        n_factors=10,
        alpha=40,
        regularization=0.1,
        iterations=40
    )
# Обучение модели
als_model.fit(sparse_matrix_csr)
    
# Визуализация процесса обучения
als_model.plot_loss()
# Out:
# Начинаем обучение ALS...
# Итерация 1/40, Loss: 4880207.2382
# Итерация 2/40, Loss: 4877101.2019
# Итерация 3/40, Loss: 4876391.3698
# Итерация 4/40, Loss: 4875979.3367
# Итерация 5/40, Loss: 4875692.7598
# Итерация 6/40, Loss: 4875478.1827
# Итерация 7/40, Loss: 4875306.8981
# Итерация 8/40, Loss: 4875165.4247
# Итерация 9/40, Loss: 4875045.8169
# Итерация 10/40, Loss: 4874942.8364
# Итерация 11/40, Loss: 4874852.8864
# Итерация 12/40, Loss: 4874773.4003
# Итерация 13/40, Loss: 4874702.4851
# Итерация 14/40, Loss: 4874638.6817
# Итерация 15/40, Loss: 4874580.9356
# Итерация 16/40, Loss: 4874528.3577
# Итерация 17/40, Loss: 4874480.2359
# Итерация 18/40, Loss: 4874435.9830
# Итерация 19/40, Loss: 4874395.1283
# Итерация 20/40, Loss: 4874357.2788
# Итерация 21/40, Loss: 4874322.1299
# Итерация 22/40, Loss: 4874289.3919
# Итерация 23/40, Loss: 4874258.7893
# Итерация 24/40, Loss: 4874230.0934
# Итерация 25/40, Loss: 4874203.1171
# Итерация 26/40, Loss: 4874177.7011
# Итерация 27/40, Loss: 4874153.7031
# Итерация 28/40, Loss: 4874130.9994
# Итерация 29/40, Loss: 4874109.4840
# Итерация 30/40, Loss: 4874089.0642
# Итерация 31/40, Loss: 4874069.6566
# Итерация 32/40, Loss: 4874051.1850
# Итерация 33/40, Loss: 4874033.5798
# Итерация 34/40, Loss: 4874016.7766
# Итерация 35/40, Loss: 4874000.7173
# Итерация 36/40, Loss: 4873985.3513
# Итерация 37/40, Loss: 4873970.6340
# Итерация 38/40, Loss: 4873956.5247
# Итерация 39/40, Loss: 4873942.9856
# Итерация 40/40, Loss: 4873929.9819

# %%
test_data, user_encoder, item_encoder = create_sparse_interaction_matrix(users_with_views, df_interactions_test, df_items)
test_data
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4686 stored elements and shape (1307, 15963)>

# %%
import pickle
with open("als_model.dump", "wb") as filee:
    pickle.dump(als_model, filee)

# %%
test_predictions = []
test_actual = []
    
for u in range(test_data.shape[0]):
    for i in range(test_data.shape[1]):
        if test_data[u, i] > 0:
                pred = als_model.predict(u, i)
                test_predictions.append(pred)
                test_actual.append(test_data[u, i])
    
# Вычисляем метрики
mse = mean_squared_error(test_actual, test_predictions)
rmse = np.sqrt(mse)
    
print(f"RMSE на тестовой выборке: {rmse:.4f}")
    
    # Демонстрация рекомендаций
print("\nДемонстрация рекомендаций:")
user_id = 0
recommended_items, scores = als_model.recommend(user_id, n_recommendations=10)
    
print(f"Топ-10 рекомендаций для пользователя {user_id}:")
for i, (item, score) in enumerate(zip(recommended_items, scores)):
    print(f"{i+1}. Item {item} (score: {score:.3f})")
    
    # Анализ факторов
print(f"\nАнализ модели:")
print(f"Размерность user_factors: {als_model.user_factors.shape}")
print(f"Размерность item_factors: {als_model.item_factors.shape}")
print(f"Общее количество параметров: {als_model.user_factors.size + als_model.item_factors.size}")
# Out:
# RMSE на тестовой выборке: 0.9302
#
# Демонстрация рекомендаций:
# Топ-10 рекомендаций для пользователя 0:
# 1. Item 8582 (score: 0.999)
# 2. Item 10230 (score: 0.822)
# 3. Item 6576 (score: 0.719)
# 4. Item 6703 (score: 0.701)
# 5. Item 2666 (score: 0.691)
# 6. Item 10530 (score: 0.637)
# 7. Item 6242 (score: 0.626)
# 8. Item 13790 (score: 0.604)
# 9. Item 7140 (score: 0.604)
# 10. Item 12931 (score: 0.591)
#
# Анализ модели:
# Размерность user_factors: (1307, 10)
# Размерность item_factors: (15963, 10)
# Общее количество параметров: 172700

# %%
test_predictions, test_actual
# Out:
# ([np.float64(0.04598363804825908),
#   np.float64(0.6044912484795563),
#   np.float64(0.3637935030624382),
#   np.float64(0.3725821365679996),
#   np.float64(0.20023693974205573),
#   np.float64(0.7738336086168622),
#   np.float64(0.04589934424179046),
#   np.float64(0.24380721415245757),
#   np.float64(-0.7702396105183044),
#   np.float64(0.48752453546634517),
#   np.float64(0.4248408118880457),
#   np.float64(0.804537046218325),
#   np.float64(-0.3145307818764615),
#   np.float64(-0.3157176871292534),
#   np.float64(0.37131209579507607),
#   np.float64(-0.2829985188810217),
#   np.float64(0.059094036669705946),
#   np.float64(0.4307399728953233),
#   np.float64(0.15502779628937186),
#   np.float64(0.5933441012901686),
#   np.float64(0.07817121705909999),
#   np.float64(0.6253225445068402),
#   np.float64(-0.1691570179269239),
#   np.float64(-0.29407244632445684),
#   np.float64(0.09094503207430932),
#   np.float64(-0.34918343446459105),
#   np.float64(0.07120990857585537),
#   np.float64(0.008421852118842358),
#   np.float64(-0.1369255946743619),
#   np.float64(-0.00014251998546143107),
#   np.float64(0.0032059127193482203),
#   np.float64(0.6819442322385335),
#   np.float64(0.09412981085189895),
#   np.float64(-1.340715474496266),
#   np.float64(0.055865923919964686),
#   np.float64(0.4921934648475756),
#   np.float64(-0.6417542670831332),
#   np.float64(-0.021896011776999638),
#   np.float64(0.08024415025701949),
#   np.float64(-0.06264959015969393),
#   np.float64(-0.06420027580316062),
#   np.float64(0.45405423361174624),
#   np.float64(-0.22791998122522747),
#   np.float64(-0.49815957195929034),
#   np.float64(0.19853377856936388),
#   np.float64(0.4394683263156645),
#   np.float64(0.6284149919631306),
#   np.float64(0.7896536701324446),
#   np.float64(-0.010829007401502977),
#   np.float64(0.25730826365863524),
#   np.float64(0.08368271358303012),
#   np.float64(0.4766905035658593),
#   np.float64(-0.0017902630277522758),
#   np.float64(0.3175587234330372),
#   np.float64(0.013131163120718152),
#   np.float64(-0.05704483800308911),
#   np.float64(0.2412551567517795),
#   np.float64(0.026460571085842145),
#   np.float64(-0.1053205845320661),
#   np.float64(0.05521162462386069),
#   np.float64(0.32850982785535215),
#   np.float64(-0.0785085171225484),
#   np.float64(-0.11670611244177374),
#   np.float64(-0.09349165885095902),
#   np.float64(-0.2848540758431913),
#   np.float64(-0.05642882383730067),
#   np.float64(-0.10715306463524546),
#   np.float64(0.06758627601204531),
#   np.float64(0.015925443321436396),
#   np.float64(0.03675837418544352),
#   np.float64(0.00823933262565177),
#   np.float64(-0.7733455032253204),
#   np.float64(0.21020990230103187),
#   np.float64(-0.16075832853889302),
#   np.float64(0.09845092880979228),
#   np.float64(0.1355720636678874),
#   np.float64(-0.44438278470398546),
#   np.float64(0.01753881693190694),
#   np.float64(-0.010216609791381915),
#   np.float64(-0.5438367798923093),
#   np.float64(0.9110513827946591),
#   np.float64(0.806421015409898),
#   np.float64(0.4710144669683486),
#   np.float64(0.028765507612626383),
#   np.float64(0.0122541978020847),
#   np.float64(-0.011357484179289348),
#   np.float64(-0.05144140246894285),
#   np.float64(-0.02827424587187085),
#   np.float64(-0.007311458817004615),
#   np.float64(-0.4569319975359004),
#   np.float64(0.16007475804567128),
#   np.float64(1.201377094211367),
#   np.float64(0.8249567998067888),
#   np.float64(0.02757998551621673),
#   np.float64(-0.6668435086465971),
#   np.float64(0.003263190392156011),
#   np.float64(0.024885419134143074),
#   np.float64(0.047801574666885546),
#   np.float64(0.034638621270502934),
#   np.float64(0.06514192782129728),
#   np.float64(-0.01384627466226916),
#   np.float64(0.5422531968674736),
#   np.float64(-0.9785781401437652),
#   np.float64(1.1567181325276705),
#   np.float64(0.24251399791085324),
#   np.float64(1.256411317925937),
#   np.float64(-1.6413451736839169),
#   np.float64(1.2488586500736403),
#   np.float64(-0.0308314375436685),
#   np.float64(0.25955712416065857),
#   np.float64(-0.037259063476204654),
#   np.float64(0.1397003766463758),
#   np.float64(0.04515701899399078),
#   np.float64(0.005136788321844669),
#   np.float64(-0.06509585957359275),
#   np.float64(0.07262897235243426),
#   np.float64(-0.025386304152234068),
#   np.float64(0.11471596249593656),
#   np.float64(-0.018333270686764155),
#   np.float64(-0.04281538481530343),
#   np.float64(-0.008287848066797276),
#   np.float64(0.0030633098399286207),
#   np.float64(0.0013088244560677108),
#   np.float64(-0.011627670645785225),
#   np.float64(0.06395539841929483),
#   np.float64(-0.057308573599668136),
#   np.float64(0.001040950594960101),
#   np.float64(-0.21215640004448388),
#   np.float64(-0.4675382317968885),
#   np.float64(0.0026811072317302355),
#   np.float64(0.0138626055950623),
#   np.float64(0.10249370623207828),
#   np.float64(-0.03367078045808834),
#   np.float64(0.03816849285509745),
#   np.float64(0.4359290786613092),
#   np.float64(-0.14269075314101126),
#   np.float64(-0.009795647495928535),
#   np.float64(0.01903789754795762),
#   np.float64(-1.5917601787364866),
#   np.float64(0.7253670178516767),
#   np.float64(0.35678092811189593),
#   np.float64(-0.0460270290457912),
#   np.float64(-0.26422266893836954),
#   np.float64(-0.020688487881900645),
#   np.float64(-0.011283540012542394),
#   np.float64(-0.3152403844739182),
#   np.float64(0.031693592638329174),
#   np.float64(0.0014878398203738686),
#   np.float64(0.9162434225768568),
#   np.float64(0.6213138016938207),
#   np.float64(0.17170196260730014),
#   np.float64(-0.04916485898493004),
#   np.float64(-0.4145360818685353),
#   np.float64(0.34492503074394504),
#   np.float64(1.5945871917672518),
#   np.float64(0.04564904158053251),
#   np.float64(-0.0842018144990333),
#   np.float64(-0.1740252063737142),
#   np.float64(-0.6984010558892425),
#   np.float64(-0.33769369665621907),
#   np.float64(0.15048205806881104),
#   np.float64(-0.0921082424764773),
#   np.float64(0.7581661876445689),
#   np.float64(0.07913855287103466),
#   np.float64(-0.12491980173562629),
#   np.float64(-0.003003908079459549),
#   np.float64(0.026642737015799882),
#   np.float64(0.01943608404952884),
#   np.float64(0.15096294543180624),
#   np.float64(0.20481196520494868),
#   np.float64(-0.04920091834447934),
#   np.float64(0.6770573507535508),
#   np.float64(-0.11074873833161855),
#   np.float64(0.22144840161004195),
#   np.float64(-0.19163480550366196),
#   np.float64(0.02737376314486631),
#   np.float64(0.013636750372355544),
#   np.float64(-0.020040059998642685),
#   np.float64(0.06679834049463657),
#   np.float64(0.004355644480786898),
#   np.float64(-0.009540366312052583),
#   np.float64(0.055603412407138675),
#   np.float64(0.058367757426163853),
#   np.float64(0.2859447684655941),
#   np.float64(0.11753173311547556),
#   np.float64(-0.1911086060958646),
#   np.float64(0.44905893095380955),
#   np.float64(-0.08552083416033161),
#   np.float64(-0.046547128291905014),
#   np.float64(0.3416501524900193),
#   np.float64(0.44396903700469464),
#   np.float64(-0.038279092682499176),
#   np.float64(0.47863686751827866),
#   np.float64(1.041347450665114),
#   np.float64(0.5168581625275087),
#   np.float64(0.03159713418989096),
#   np.float64(-0.41155014217008246),
#   np.float64(-0.04124267221690705),
#   np.float64(-0.010145906194492547),
#   np.float64(0.04345150673885667),
#   np.float64(-0.4419395564884804),
#   np.float64(0.35324884224964265),
#   np.float64(-0.05050378814707922),
#   np.float64(-0.0889391419825593),
#   np.float64(0.08313921589449483),
#   np.float64(0.2795942973504688),
#   np.float64(1.0670126266871172),
#   np.float64(0.36196789938348517),
#   np.float64(0.06997808404263967),
#   np.float64(-0.014625048818964865),
#   np.float64(0.052536030863339384),
#   np.float64(-0.011997029815514267),
#   np.float64(0.12351013913810133),
#   np.float64(0.39711237011540357),
#   np.float64(-0.015615692395943546),
#   np.float64(0.2158189867334462),
#   np.float64(-0.05271167230449012),
#   np.float64(-0.007158783856258349),
#   np.float64(0.19920433575152813),
#   np.float64(0.05809149307645205),
#   np.float64(-0.13137934816466845),
#   np.float64(-0.003983238751686837),
#   np.float64(-0.2200135439438123),
#   np.float64(0.04800651140308168),
#   np.float64(0.09271974763313502),
#   np.float64(0.07923601354565109),
#   np.float64(-0.07723213171296311),
#   np.float64(-0.015342839186327511),
#   np.float64(0.04634337384108492),
#   np.float64(0.15910922778256267),
#   np.float64(-0.23100973759929605),
#   np.float64(0.2711152017113047),
#   np.float64(-0.18752275488454087),
#   np.float64(0.11100961909392563),
#   np.float64(0.407289467233914),
#   np.float64(0.3135250713492461),
#   np.float64(0.23330014287974052),
#   np.float64(0.32060583667449155),
#   np.float64(0.4188265497901253),
#   np.float64(0.4504457835137092),
#   np.float64(-0.23694433825351488),
#   np.float64(0.7118414361555757),
#   np.float64(-0.8991762124349351),
#   np.float64(-0.026204615655304977),
#   np.float64(-0.1865037706826168),
#   np.float64(-0.2618704488789791),
#   np.float64(0.12544308513882982),
#   np.float64(-0.060322270955428595),
#   np.float64(-0.09136680101231973),
#   np.float64(0.2112598584175537),
#   np.float64(0.4180209318306204),
#   np.float64(0.004026680639863125),
#   np.float64(0.0009778272741115114),
#   np.float64(-0.06464455965531093),
#   np.float64(0.003886607678430835),
#   np.float64(0.024969094882490075),
#   np.float64(-0.006152067221272713),
#   np.float64(0.2961798700098089),
#   np.float64(0.024214718262281054),
#   np.float64(0.2513887354275283),
#   np.float64(0.16859361364749514),
#   np.float64(-0.3605388232995157),
#   np.float64(0.3563569057703209),
#   np.float64(-0.10760217000654473),
#   np.float64(0.28718794210780224),
#   np.float64(0.5290865525713474),
#   np.float64(0.2514341394430382),
#   np.float64(0.09187386765000828),
#   np.float64(-0.6382862381141943),
#   np.float64(0.09033293261829473),
#   np.float64(-0.46163593216047),
#   np.float64(-0.8873114093469703),
#   np.float64(-0.34160121159102946),
#   np.float64(0.016121305900278823),
#   np.float64(-0.10349222993167685),
#   np.float64(0.09663909054516087),
#   np.float64(-0.34158951735037685),
#   np.float64(0.2622872344381363),
#   np.float64(0.6240998675033487),
#   np.float64(0.06338156701679958),
#   np.float64(0.016028213141294),
#   np.float64(-0.263860987408813),
#   np.float64(0.27314128586649544),
#   np.float64(-0.0600134490058172),
#   np.float64(0.17388330861722778),
#   np.float64(-0.062412137137102294),
#   np.float64(-0.018239534034089254),
#   np.float64(0.014785297246732611),
#   np.float64(0.4559535715074343),
#   np.float64(0.3029512962670569),
#   np.float64(0.1499005779778945),
#   np.float64(-0.08708377776043634),
#   np.float64(0.044160244487389026),
#   np.float64(0.516193013407231),
#   np.float64(0.48127629534926336),
#   np.float64(-0.2561737318054411),
#   np.float64(-0.5681148329246881),
#   np.float64(-0.0723908684291658),
#   np.float64(-0.09982843916917011),
#   np.float64(0.01921434971498871),
#   np.float64(0.0015107824715350298),
#   np.float64(0.0111864764652593),
#   np.float64(-0.048840157545261234),
#   np.float64(0.1743451117570911),
#   np.float64(0.1292300556808248),
#   np.float64(0.45974683932281346),
#   np.float64(-0.23679568762608974),
#   np.float64(-0.05317750400535121),
#   np.float64(0.041600445958026686),
#   np.float64(-0.04719308752577354),
#   np.float64(-0.02415175420349924),
#   np.float64(-0.04135024418864545),
#   np.float64(0.07776803035306365),
#   np.float64(-0.0035869747929273975),
#   np.float64(-0.003432629743991656),
#   np.float64(-0.8943987200444142),
#   np.float64(0.6475499143075347),
#   np.float64(0.24041750412593324),
#   np.float64(0.5012562198039116),
#   np.float64(0.568423815621628),
#   np.float64(0.04762956655587468),
#   np.float64(0.009801257643809687),
#   np.float64(-0.020760996835731706),
#   np.float64(0.0535847756113814),
#   np.float64(0.48427489165788173),
#   np.float64(0.5648423432441557),
#   np.float64(0.021339645107673565),
#   np.float64(0.02066294587764421),
#   np.float64(0.38469358360124084),
#   np.float64(0.5368466502408635),
#   np.float64(-0.8830542679726404),
#   np.float64(-0.0456744870084709),
#   np.float64(-0.05476823677373205),
#   np.float64(0.19160618750347602),
#   np.float64(0.15363141843261463),
#   np.float64(0.1792060952909564),
#   np.float64(-0.14247074166735815),
#   np.float64(-0.1278202743517196),
#   np.float64(0.09266467467687262),
#   np.float64(0.033015693421138054),
#   np.float64(-0.3751080559509974),
#   np.float64(-0.018494172188709624),
#   np.float64(-0.365480169088813),
#   np.float64(0.4006080405487583),
#   np.float64(0.8697241969773045),
#   np.float64(-0.050487687795421364),
#   np.float64(-0.03932163607760826),
#   np.float64(-0.010255893517164062),
#   np.float64(0.018196958592397033),
#   np.float64(0.0007952992574220676),
#   np.float64(-0.6064730937974795),
#   np.float64(-0.01841026977661226),
#   np.float64(0.03533922165995174),
#   np.float64(-0.49838122792860895),
#   np.float64(0.9406343753236007),
#   np.float64(0.5267556320529793),
#   np.float64(0.03830254499466901),
#   np.float64(-0.2548414758953934),
#   np.float64(0.3281270798795851),
#   np.float64(-0.06105149568347311),
#   np.float64(-0.0238312251350352),
#   np.float64(-0.027695997553894645),
#   np.float64(0.053407560578964536),
#   np.float64(0.023478281180998192),
#   np.float64(0.027626947924456496),
#   np.float64(-0.25038423602659077),
#   np.float64(-0.09682398489856482),
#   np.float64(0.03368784694116237),
#   np.float64(1.4011846525019853),
#   np.float64(0.021250184984157122),
#   np.float64(0.03296974142455301),
#   np.float64(0.05602094025412793),
#   np.float64(0.07177169031172571),
#   np.float64(0.0349519779114237),
#   np.float64(-0.049340603201965386),
#   np.float64(-0.007821229826355334),
#   np.float64(0.005991736165761702),
#   np.float64(-0.08212812807598917),
#   np.float64(0.08751518845115072),
#   np.float64(-0.0021861766703911616),
#   np.float64(-0.012644382673928525),
#   np.float64(-0.5840733363481642),
#   np.float64(0.6247066308095026),
#   np.float64(0.011555742693234465),
#   np.float64(0.6518594291641241),
#   np.float64(-0.03422333779924065),
#   np.float64(-0.5016017615957624),
#   np.float64(0.3736947925775679),
#   np.float64(-0.08707656108708897),
#   np.float64(0.24218057050196976),
#   np.float64(0.008144396997195298),
#   np.float64(-0.25525263283807575),
#   np.float64(0.4372442462451778),
#   np.float64(0.10796626028443895),
#   np.float64(0.09609918118259608),
#   np.float64(-0.052367952591834986),
#   np.float64(0.10572035478530184),
#   np.float64(0.053162134520255575),
#   np.float64(0.408678674633852),
#   np.float64(-0.3405404083837741),
#   np.float64(-0.2219428116601227),
#   np.float64(-0.01836437490200075),
#   np.float64(0.15537704264384875),
#   np.float64(0.042929723120896504),
#   np.float64(0.06396646871121167),
#   np.float64(-0.014920107691948716),
#   np.float64(-0.005032162446001568),
#   np.float64(-0.03671577034026656),
#   np.float64(-0.00910999229000069),
#   np.float64(0.0438151944114437),
#   np.float64(0.031971810161486265),
#   np.float64(0.11728056279858405),
#   np.float64(0.8767109741395547),
#   np.float64(1.151380913067279),
#   np.float64(-0.026334387671836327),
#   np.float64(-0.01768452775589111),
#   np.float64(-0.1252887738427112),
#   np.float64(-0.10530064015307537),
#   np.float64(0.007719572169648965),
#   np.float64(0.024734549122824353),
#   np.float64(0.0019312687188901753),
#   np.float64(0.02773486339708688),
#   np.float64(-0.07723896605518255),
#   np.float64(0.34033970151073534),
#   np.float64(0.004605495575165867),
#   np.float64(0.00599208808853208),
#   np.float64(-0.044275733192238674),
#   np.float64(1.353998856293205),
#   np.float64(0.5557616976646731),
#   np.float64(-0.15304396281394486),
#   np.float64(-1.1029325559570275),
#   np.float64(-0.0007564048287661928),
#   np.float64(-0.00012210758604221014),
#   np.float64(0.0017647163939756244),
#   np.float64(-0.005078103422287599),
#   np.float64(0.04320036520263061),
#   np.float64(-0.9520030608953138),
#   np.float64(0.09649745854756905),
#   np.float64(-0.9264215504080004),
#   np.float64(0.38632910398821424),
#   np.float64(0.06867821687232155),
#   np.float64(-0.1764331569501614),
#   np.float64(0.28524568922745364),
#   np.float64(-0.1446000749688241),
#   np.float64(0.11882873216838404),
#   np.float64(-0.015683183388385646),
#   np.float64(0.04840583877605259),
#   np.float64(0.5750815862209476),
#   np.float64(0.23781889172780135),
#   np.float64(0.28364739698002467),
#   np.float64(0.01645760554153395),
#   np.float64(-0.21960584279799836),
#   np.float64(0.01339902103872134),
#   np.float64(0.015689310280506345),
#   np.float64(0.146617847815054),
#   np.float64(0.5034228025297718),
#   np.float64(0.013806153168491203),
#   np.float64(0.04243218094237721),
#   np.float64(0.029527969108203385),
#   np.float64(-0.0696645488247765),
#   np.float64(-0.16301972556714206),
#   np.float64(0.23121296167421818),
#   np.float64(-0.3325711965520528),
#   np.float64(-0.05247992736636059),
#   np.float64(-0.05084966914003791),
#   np.float64(-0.1790607977808131),
#   np.float64(-0.0826510523267594),
#   np.float64(-0.09479332014275527),
#   np.float64(-0.3517392135370043),
#   np.float64(-0.07145288436525833),
#   np.float64(0.3465700181575146),
#   np.float64(0.039877482514506284),
#   np.float64(-0.16706710891869161),
#   np.float64(-0.005163780306399514),
#   np.float64(-0.740046407902264),
#   np.float64(0.28229764356932696),
#   np.float64(-1.066582646879164),
#   np.float64(0.38373741461639743),
#   np.float64(0.8169568403478144),
#   np.float64(-0.0138701484633641),
#   np.float64(0.3833330921906513),
#   np.float64(0.8835641608845253),
#   np.float64(0.3303254064505825),
#   np.float64(0.5391487900533093),
#   np.float64(-0.006510048078577915),
#   np.float64(0.2675320960792344),
#   np.float64(-0.07641059229617767),
#   np.float64(0.031009338870661575),
#   np.float64(0.07140186844496528),
#   np.float64(0.044248254705388325),
#   np.float64(0.033710661230961475),
#   np.float64(0.31249994443786167),
#   np.float64(0.014247130073628402),
#   np.float64(-0.06809362158715039),
#   np.float64(0.005631549171526075),
#   np.float64(0.5101209776117319),
#   np.float64(0.07054566511808832),
#   np.float64(-0.11532012655143532),
#   np.float64(-0.013478495218582591),
#   np.float64(-0.0410569433445053),
#   np.float64(0.04274596550484379),
#   np.float64(-0.012441303179610366),
#   np.float64(0.052463508638122755),
#   np.float64(0.09982575504973833),
#   np.float64(0.04277534705282748),
#   np.float64(0.049346378561553855),
#   np.float64(0.09732969681452604),
#   np.float64(0.3483172861372271),
#   np.float64(0.12316557821964175),
#   np.float64(-0.19521000315556777),
#   np.float64(0.10197973808855307),
#   np.float64(0.02163213809939136),
#   np.float64(-0.16879187156934755),
#   np.float64(-0.6722233742137536),
#   np.float64(0.2651745396276273),
#   np.float64(0.5283858200040554),
#   np.float64(-1.3730989447142306),
#   np.float64(0.9979734970865192),
#   np.float64(-0.1428572850565497),
#   np.float64(-0.20345513262154177),
#   np.float64(0.047014650605328834),
#   np.float64(-0.0851143388585743),
#   np.float64(0.05355224026397329),
#   np.float64(0.43454479192083006),
#   np.float64(0.4490528962014284),
#   np.float64(0.14538838968456386),
#   np.float64(-0.44271388660033595),
#   np.float64(-0.29321985811018775),
#   np.float64(-0.5634355201741656),
#   np.float64(-0.040283015594487194),
#   np.float64(0.3129114433707752),
#   np.float64(-0.03696408559525321),
#   np.float64(0.12268938557517206),
#   np.float64(-0.03235970734116988),
#   np.float64(0.2518916805745059),
#   np.float64(-0.10524621920679557),
#   np.float64(0.11792898160942147),
#   np.float64(-0.017278490418015102),
#   np.float64(1.0046344763675654),
#   np.float64(-0.32118903639922436),
#   np.float64(-0.4489065548750923),
#   np.float64(-0.2890373881127215),
#   np.float64(1.5589869419685307),
#   np.float64(-0.03699461795456242),
#   np.float64(-2.189481979598349),
#   np.float64(-0.5412740204098344),
#   np.float64(-0.04004414231693374),
#   np.float64(-0.010296880076848147),
#   np.float64(0.006811703523220551),
#   np.float64(-0.0045274615808133115),
#   np.float64(0.04492183747274616),
#   np.float64(-0.010814806799242275),
#   np.float64(0.04731696791212896),
#   np.float64(0.012542638583134268),
#   np.float64(-0.21082896828891404),
#   np.float64(0.2396118264111176),
#   np.float64(-0.19979959914718703),
#   np.float64(0.05362221670086085),
#   np.float64(0.015102881554349037),
#   np.float64(-0.017750244002876222),
#   np.float64(0.5584099020183306),
#   np.float64(1.7951054586652821),
#   np.float64(0.13057819848915123),
#   np.float64(0.011636593976763148),
#   np.float64(-0.3914375053551927),
#   np.float64(-0.3341837071774621),
#   np.float64(-0.011833134525572735),
#   np.float64(-0.1150175113343019),
#   np.float64(-0.5105773562704374),
#   np.float64(-0.3099334474711422),
#   np.float64(-0.5052644889821599),
#   np.float64(0.040238098947575414),
#   np.float64(0.5024189564945584),
#   np.float64(1.5060059827910763),
#   np.float64(0.47171171060150247),
#   np.float64(0.0713864518745395),
#   np.float64(0.0225070603102833),
#   np.float64(0.21314572909566257),
#   np.float64(0.49500900274302906),
#   np.float64(0.19841099339004517),
#   np.float64(-0.5915896504370082),
#   np.float64(-0.014451348398662913),
#   np.float64(-0.6265221835210371),
#   np.float64(-0.06637956800895432),
#   np.float64(0.32540631580229123),
#   np.float64(0.7541253391418189),
#   np.float64(0.011044385510434998),
#   np.float64(0.6193570305784094),
#   np.float64(0.0006976651060946579),
#   np.float64(-0.09984255887332821),
#   np.float64(0.0402800426986225),
#   np.float64(-0.06360026887790898),
#   np.float64(-0.07935404126593536),
#   np.float64(-0.03535639921171508),
#   np.float64(0.054509813361032784),
#   np.float64(0.23554230180772046),
#   np.float64(-0.21639934977663786),
#   np.float64(-0.23326580964081392),
#   np.float64(1.1349530020983718),
#   np.float64(0.4177756827866212),
#   np.float64(0.3411259986488845),
#   np.float64(0.0074217880013383525),
#   np.float64(0.06647379077578958),
#   np.float64(0.01584641547866614),
#   np.float64(0.5491421673110415),
#   np.float64(-1.5683493386907568),
#   np.float64(-0.4586273440250812),
#   np.float64(-0.021968959965447732),
#   np.float64(-0.021941635925001524),
#   np.float64(0.21613142415630113),
#   np.float64(0.2071380727205102),
#   np.float64(0.270164489052778),
#   np.float64(0.694487033246222),
#   np.float64(-0.4555244034378826),
#   np.float64(0.02554844101789961),
#   np.float64(-0.04755698393531825),
#   np.float64(0.002168303491984106),
#   np.float64(0.28534476627963734),
#   np.float64(0.5659212325870038),
#   np.float64(-0.8481737557137145),
#   np.float64(-0.43091907413071173),
#   np.float64(0.4551057715280817),
#   np.float64(-0.09466115408320744),
#   np.float64(0.3151350145607088),
#   np.float64(0.02149974764997463),
#   np.float64(0.3738326278067483),
#   np.float64(0.5544414531427727),
#   np.float64(-0.9866495760771231),
#   np.float64(0.21060865096525633),
#   np.float64(0.9012819251278543),
#   np.float64(0.7422523620178937),
#   np.float64(-0.5363909719619814),
#   np.float64(-0.2311243151189264),
#   np.float64(0.15490448145977184),
#   np.float64(-0.24753864241751286),
#   np.float64(-0.054993249559496894),
#   np.float64(0.25011230906821386),
#   np.float64(0.27081162837591544),
#   np.float64(0.05124748395926655),
#   np.float64(0.07004089956574343),
#   np.float64(0.07025392147714883),
#   np.float64(0.04141482619616642),
#   np.float64(0.0002566726174642774),
#   np.float64(0.018325900448634667),
#   np.float64(0.16839869607028782),
#   np.float64(0.6719868954038948),
#   np.float64(0.0177986020312555),
#   np.float64(0.0016660210146079795),
#   np.float64(-0.031002762863026976),
#   np.float64(-0.05856843250045888),
#   np.float64(0.23914384449855397),
#   np.float64(-0.16034617807668336),
#   np.float64(0.027139245023183517),
#   np.float64(-0.09363644761295739),
#   np.float64(0.023383004507493556),
#   np.float64(0.41966951620030807),
#   np.float64(-0.048927613167332344),
#   np.float64(-1.5342770145787148),
#   np.float64(0.3459764046301862),
#   np.float64(-0.07060245929767148),
#   np.float64(0.31523934258614417),
#   np.float64(0.07827950526005188),
#   np.float64(0.27852207126851447),
#   np.float64(-0.3483740732675499),
#   np.float64(0.2449636499595463),
#   np.float64(-0.30793988880807727),
#   np.float64(0.006115035514650233),
#   np.float64(0.4217120529649729),
#   np.float64(0.3107652652404952),
#   np.float64(-0.17147117219244984),
#   np.float64(-0.06434501435899276),
#   np.float64(0.17766107190866087),
#   np.float64(0.20096351378362243),
#   np.float64(0.42271943277637536),
#   np.float64(-0.13546520861548028),
#   np.float64(0.09869969957000424),
#   np.float64(0.6204138833502041),
#   np.float64(-0.15489294800545814),
#   np.float64(0.1342155193405912),
#   np.float64(0.657157089228616),
#   np.float64(-0.27177047970559154),
#   np.float64(0.05941015038650957),
#   np.float64(0.5348876717049564),
#   np.float64(0.6523721471006033),
#   np.float64(-0.10187870608694356),
#   np.float64(-0.01134730887760943),
#   np.float64(0.012986688605202511),
#   np.float64(0.11155481385765663),
#   np.float64(0.037096796601162906),
#   np.float64(0.28151432800770704),
#   np.float64(-0.07071128727283683),
#   np.float64(0.5242211298677455),
#   np.float64(-0.06042944006028216),
#   np.float64(0.1241953733617745),
#   np.float64(-0.016954851393252146),
#   np.float64(-0.07480744439879504),
#   np.float64(0.7117495226282564),
#   np.float64(-0.03480581094299576),
#   np.float64(-0.19539435273970632),
#   np.float64(0.04118257169052934),
#   np.float64(-0.13366532258046582),
#   np.float64(-0.13943590357306335),
#   np.float64(-0.4775415203235186),
#   np.float64(-0.25948705506328656),
#   np.float64(-0.07796800595968177),
#   np.float64(-0.13571832715556456),
#   np.float64(0.01030803821579217),
#   np.float64(0.3030492846264343),
#   np.float64(-0.027945133453211448),
#   np.float64(0.5828783126334011),
#   np.float64(-0.28040767215364587),
#   np.float64(0.3560267464716125),
#   np.float64(-0.3817126936579431),
#   np.float64(-0.0823850998554206),
#   np.float64(0.4736301879697275),
#   np.float64(0.00859744858342204),
#   np.float64(0.009218201691869841),
#   np.float64(0.05280090221699977),
#   np.float64(0.025681128648733478),
#   np.float64(0.019202972305824333),
#   np.float64(0.01796738336487976),
#   np.float64(0.072678228616145),
#   np.float64(-0.02848650754753708),
#   np.float64(-0.10280556314130869),
#   np.float64(-0.042510068135039394),
#   np.float64(0.05299896831935396),
#   np.float64(-0.10833920544766741),
#   np.float64(0.7730573494694976),
#   np.float64(1.3435508496215267),
#   np.float64(-0.368896091323251),
#   np.float64(-0.07928260457422757),
#   np.float64(-0.04310378413860346),
#   np.float64(-0.07462802079714496),
#   np.float64(0.025307082562909755),
#   np.float64(-0.04133400749068505),
#   np.float64(0.6659400732101546),
#   np.float64(0.005726199137420748),
#   np.float64(0.0031575482785830265),
#   np.float64(-0.013242278446186246),
#   np.float64(-0.0008325571382343448),
#   np.float64(-0.0005124837123926401),
#   np.float64(0.004466869501743568),
#   np.float64(0.4056805149196668),
#   np.float64(0.5061391218058795),
#   np.float64(-0.1092837794026729),
#   np.float64(0.2506702778905462),
#   np.float64(0.44972501174578483),
#   np.float64(0.7966203924199836),
#   np.float64(-0.0048643256900177895),
#   np.float64(-0.03839020057429568),
#   np.float64(-0.003894744568312706),
#   np.float64(-0.023105963331718424),
#   np.float64(-0.18380601774187394),
#   np.float64(0.029755710097319744),
#   np.float64(-0.001504440869406964),
#   np.float64(0.5371774733185101),
#   np.float64(-0.12771503898506253),
#   np.float64(0.9147846179218179),
#   np.float64(0.018069623153527545),
#   np.float64(-0.0040245155208143875),
#   np.float64(0.6347498497172525),
#   np.float64(-0.003188971400912544),
#   np.float64(0.9902572002233462),
#   np.float64(-0.3214259433721425),
#   np.float64(0.5674382850200773),
#   np.float64(-0.1346172858326635),
#   np.float64(-0.03260579261284207),
#   np.float64(-0.3488185858374724),
#   np.float64(-0.411835096055721),
#   np.float64(0.06848727632027425),
#   np.float64(0.1722526802032332),
#   np.float64(-0.12472185489059474),
#   np.float64(-0.48668574500085615),
#   np.float64(-0.009233567764196668),
#   np.float64(-0.1913381472269008),
#   np.float64(0.2953884212743582),
#   np.float64(0.40058349000386534),
#   np.float64(-0.12445041581261902),
#   np.float64(0.0336817943486755),
#   np.float64(-0.05089370819033659),
#   np.float64(0.008885776054407175),
#   np.float64(0.011889203090448712),
#   np.float64(0.5975060257630798),
#   np.float64(0.4111913637315823),
#   np.float64(0.20154172745830437),
#   np.float64(0.45022862797087393),
#   np.float64(-0.2808029815784199),
#   np.float64(0.015161906894172367),
#   np.float64(0.03887687377389609),
#   np.float64(0.002606978930951502),
#   np.float64(-0.03621169577896917),
#   np.float64(0.20278558679363404),
#   np.float64(1.6008526494113904),
#   np.float64(0.017473881164194925),
#   np.float64(0.042731275094321015),
#   np.float64(-0.10919967936138315),
#   np.float64(0.016386140838464285),
#   np.float64(0.8975553444584368),
#   np.float64(0.5519651056313782),
#   np.float64(-0.09587633643571584),
#   np.float64(0.4114282814273336),
#   np.float64(0.0759421980153052),
#   np.float64(0.030784763820959387),
#   np.float64(0.04519092107664188),
#   np.float64(-0.003812762984467915),
#   np.float64(1.6083492145926874),
#   np.float64(-0.6318205879340457),
#   np.float64(0.0055302500685907394),
#   np.float64(0.22448435923819016),
#   np.float64(0.03389891839444891),
#   np.float64(-0.010951334902295993),
#   np.float64(1.012983170168244),
#   np.float64(-0.2352712604409254),
#   np.float64(-0.06615896298635716),
#   np.float64(-0.016117109486430883),
#   np.float64(0.05983102402745707),
#   np.float64(-0.7747836198040866),
#   np.float64(-0.13748107664132148),
#   np.float64(-0.3388517590858092),
#   np.float64(0.019351229755509815),
#   np.float64(-0.0921726096766178),
#   np.float64(0.7084930852903898),
#   np.float64(-0.003921069795134237),
#   np.float64(0.8249985988025773),
#   np.float64(1.2603981782707516),
#   np.float64(0.9307109869588939),
#   np.float64(0.0027418161694026623),
#   np.float64(-0.07162411654419355),
#   np.float64(-0.03196398575545218),
#   np.float64(-0.02870014271940807),
#   np.float64(-0.01848389894221639),
#   np.float64(-0.3137630057069451),
#   np.float64(0.05151003093149728),
#   np.float64(-0.03360541115273038),
#   np.float64(0.37292599324499326),
#   np.float64(0.7540032108988005),
#   np.float64(0.3874725832681441),
#   np.float64(-0.01747001159513715),
#   np.float64(-1.3940280227840578),
#   np.float64(0.20451960073881592),
#   np.float64(-0.0035042177435183767),
#   np.float64(0.006093641277818065),
#   np.float64(-0.05984289856221134),
#   np.float64(-0.02654617222324288),
#   np.float64(0.04163528853064999),
#   np.float64(0.024378313870644177),
#   np.float64(-0.06792542565223132),
#   np.float64(-0.02834182182492543),
#   np.float64(-0.015950602982275713),
#   np.float64(0.018721081927950807),
#   np.float64(0.027611878871483482),
#   np.float64(-1.0826396013045594),
#   np.float64(0.6010364275569995),
#   np.float64(0.3373270681660978),
#   np.float64(0.37423339893513485),
#   np.float64(-0.1251539384739712),
#   np.float64(0.614602030771738),
#   np.float64(0.5843407730924519),
#   np.float64(-0.19648803750390548),
#   np.float64(0.02391841191792698),
#   np.float64(0.4766325224607321),
#   np.float64(0.2354829460383036),
#   np.float64(-0.12313701115959087),
#   np.float64(-0.25570863880701966),
#   np.float64(-0.48057499290591715),
#   np.float64(-0.0483632459062845),
#   np.float64(-0.06451508986442593),
#   np.float64(0.4359622570523462),
#   np.float64(0.5394514215400243),
#   np.float64(-0.06079847467798274),
#   np.float64(-0.5579917109699946),
#   np.float64(0.001810265534067546),
#   np.float64(-0.0335504000509885),
#   np.float64(0.014931716749699977),
#   np.float64(-0.4131655663869076),
#   np.float64(-0.006637429854484577),
#   np.float64(-0.1138904846658151),
#   np.float64(-0.05798522394182073),
#   np.float64(-1.0142250512297997),
#   np.float64(0.5544935332559139),
#   np.float64(-0.0884617201601054),
#   np.float64(0.1263572351628392),
#   np.float64(0.2860118731826638),
#   np.float64(-0.04650191172619063),
#   np.float64(-0.03500237924890984),
#   np.float64(-0.010087533330570218),
#   np.float64(-0.04238489493414568),
#   np.float64(0.047215510459826256),
#   np.float64(0.08379176462932653),
#   np.float64(0.300039837157832),
#   np.float64(0.5080243345184292),
#   np.float64(0.22383742496950867),
#   np.float64(-0.3189209140031166),
#   np.float64(0.8104111740630618),
#   np.float64(0.2175264105863136),
#   np.float64(-1.3460085920299303),
#   np.float64(0.29767422651737097),
#   np.float64(0.5730589142566888),
#   np.float64(1.029382585144252),
#   np.float64(0.05334253393734507),
#   np.float64(0.3524085153539317),
#   np.float64(-0.02218876398489599),
#   np.float64(-0.022190052028769152),
#   np.float64(0.12196885598169017),
#   np.float64(-0.1380943976033348),
#   np.float64(-0.8822515911757731),
#   np.float64(0.0711159951140239),
#   np.float64(0.04674804434254125),
#   np.float64(0.033637611390096925),
#   np.float64(0.03237450078487534),
#   np.float64(-0.07044305076768542),
#   np.float64(0.06965845099986238),
#   np.float64(-0.021072533389611074),
#   np.float64(0.43076335643040103),
#   np.float64(-1.0703774423555037),
#   np.float64(0.8713425873825621),
#   np.float64(0.8696372367847334),
#   np.float64(0.002765979840113546),
#   np.float64(0.04749121042396161),
#   np.float64(0.025218029503270224),
#   np.float64(0.05762636235615278),
#   np.float64(-0.010842680319177884),
#   np.float64(0.0029738396158957513),
#   np.float64(0.027587695829475085),
#   np.float64(-0.013946852156318038),
#   np.float64(-0.012798899844133517),
#   np.float64(-0.04954408923276851),
#   np.float64(0.4067198601226025),
#   np.float64(1.296793329185514),
#   np.float64(-0.03945558789210091),
#   np.float64(-0.1034727840176373),
#   np.float64(-0.09515453733376857),
#   np.float64(0.02477971882327991),
#   np.float64(-0.041177107467043075),
#   np.float64(0.23581758444055215),
#   np.float64(0.3074449875782729),
#   np.float64(0.11600776381065336),
#   np.float64(0.7228596557542862),
#   np.float64(-0.4276395124260688),
#   np.float64(0.005679154132926706),
#   np.float64(0.03642907672813809),
#   np.float64(0.4274687969229615),
#   np.float64(0.5987228928151216),
#   np.float64(0.0642152217840574),
#   np.float64(0.5617039124983602),
#   np.float64(-0.046900016993079635),
#   np.float64(0.04734148776077595),
#   np.float64(-0.11279522952882963),
#   np.float64(0.13584300994629617),
#   np.float64(-0.06727153424320434),
#   np.float64(0.06456113990387596),
#   np.float64(-0.020789207862366862),
#   np.float64(-0.0011190060931662404),
#   np.float64(0.30416530337820763),
#   np.float64(-0.28194924240064656),
#   np.float64(0.031539079027124696),
#   np.float64(-0.3507290282903512),
#   np.float64(0.1010150083576775),
#   np.float64(-0.189495261309166),
#   np.float64(0.008281958661316813),
#   np.float64(0.001870572897948297),
#   np.float64(-0.1702070009089543),
#   np.float64(0.021360687707555386),
#   np.float64(0.004663509815399627),
#   np.float64(-0.29125970896260855),
#   np.float64(0.178656726448775),
#   np.float64(1.0198689408837078),
#   np.float64(0.612977497981396),
#   np.float64(-0.11409958020228375),
#   np.float64(-0.4228092853256213),
#   np.float64(0.0003954302501265389),
#   np.float64(0.03211575459665063),
#   np.float64(0.006698437040894692),
#   np.float64(0.015708290310432922),
#   np.float64(-0.05480492140855263),
#   np.float64(-0.001396103591370129),
#   np.float64(0.14493884968744017),
#   np.float64(0.4857730389320623),
#   np.float64(-0.3537230889448617),
#   np.float64(0.015090688974693553),
#   np.float64(-1.3268331673012717),
#   np.float64(-0.027393664726055134),
#   np.float64(-0.019525221397877074),
#   np.float64(-0.0742622903353225),
#   np.float64(0.051179796953734084),
#   np.float64(1.4636882073307529),
#   np.float64(0.29223263820372425),
#   np.float64(0.056743637122683245),
#   np.float64(-0.498348447926084),
#   np.float64(-0.6347980041633747),
#   np.float64(-0.27560150646290377),
#   np.float64(-0.05141377635042907),
#   np.float64(-0.10432314336309305),
#   np.float64(-0.8937694557073033),
#   np.float64(-0.0389768225582046),
#   np.float64(0.013742881535094799),
#   np.float64(0.35964615040438536),
#   np.float64(-0.1493473642482946),
#   np.float64(0.10438987586198442),
#   np.float64(0.06373938403632988),
#   ...],
#  [np.float64(0.77),
#   np.float64(0.66),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(0.8),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.78),
#   np.float64(0.99),
#   np.float64(0.97),
#   np.float64(0.97),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.63),
#   np.float64(0.86),
#   np.float64(0.65),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.73),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.76),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.83),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.87),
#   np.float64(1.0),
#   np.float64(0.77),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.6),
#   np.float64(1.0),
#   np.float64(0.74),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(0.88),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.65),
#   np.float64(0.86),
#   np.float64(0.72),
#   np.float64(0.58),
#   np.float64(0.77),
#   np.float64(0.56),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.6),
#   np.float64(0.95),
#   np.float64(0.96),
#   np.float64(0.97),
#   np.float64(0.63),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.71),
#   np.float64(0.52),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.67),
#   np.float64(0.94),
#   np.float64(0.92),
#   np.float64(0.84),
#   np.float64(0.99),
#   np.float64(0.91),
#   np.float64(0.78),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(0.64),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.65),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.67),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.83),
#   np.float64(0.59),
#   np.float64(1.0),
#   np.float64(0.62),
#   np.float64(0.75),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.78),
#   np.float64(1.0),
#   np.float64(0.84),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.84),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.62),
#   np.float64(0.98),
#   np.float64(0.51),
#   np.float64(1.0),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(0.99),
#   np.float64(0.83),
#   np.float64(0.99),
#   np.float64(0.88),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.73),
#   np.float64(0.87),
#   np.float64(0.81),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.54),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.82),
#   np.float64(0.67),
#   np.float64(0.78),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.88),
#   np.float64(0.98),
#   np.float64(0.75),
#   np.float64(0.66),
#   np.float64(0.99),
#   np.float64(0.96),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.58),
#   np.float64(1.0),
#   np.float64(0.54),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(0.75),
#   np.float64(0.95),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.64),
#   np.float64(1.0),
#   np.float64(0.54),
#   np.float64(0.54),
#   np.float64(0.71),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.86),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.91),
#   np.float64(0.93),
#   np.float64(0.97),
#   np.float64(0.57),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.67),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.75),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.96),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.83),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.99),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.85),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.53),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.74),
#   np.float64(0.62),
#   np.float64(1.0),
#   np.float64(0.61),
#   np.float64(0.81),
#   np.float64(1.0),
#   np.float64(0.85),
#   np.float64(0.65),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.57),
#   np.float64(0.81),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(0.98),
#   np.float64(0.52),
#   np.float64(0.67),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(0.68),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.6),
#   np.float64(0.51),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.71),
#   np.float64(0.87),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.72),
#   np.float64(0.67),
#   np.float64(0.58),
#   np.float64(0.61),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.81),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(0.9),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(0.83),
#   np.float64(1.0),
#   np.float64(0.72),
#   np.float64(1.0),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.97),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.86),
#   np.float64(1.0),
#   np.float64(0.6),
#   np.float64(1.0),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.82),
#   np.float64(0.94),
#   np.float64(0.56),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(0.81),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.73),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(0.74),
#   np.float64(0.74),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(0.62),
#   np.float64(0.93),
#   np.float64(0.9),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.71),
#   np.float64(0.97),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.9),
#   np.float64(0.98),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.56),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.54),
#   np.float64(0.88),
#   np.float64(0.64),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.64),
#   np.float64(0.91),
#   np.float64(0.61),
#   np.float64(0.96),
#   np.float64(0.73),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.75),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.83),
#   np.float64(0.53),
#   np.float64(0.64),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.97),
#   np.float64(0.96),
#   np.float64(0.93),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.57),
#   np.float64(1.0),
#   np.float64(0.77),
#   np.float64(0.62),
#   np.float64(0.98),
#   np.float64(0.84),
#   np.float64(0.6),
#   np.float64(0.99),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(0.81),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(0.99),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(0.71),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.87),
#   np.float64(0.89),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.78),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(0.7),
#   np.float64(0.93),
#   np.float64(0.87),
#   np.float64(0.64),
#   np.float64(0.63),
#   np.float64(1.0),
#   np.float64(0.82),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.57),
#   np.float64(1.0),
#   np.float64(0.6),
#   np.float64(0.95),
#   np.float64(0.86),
#   np.float64(0.96),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.62),
#   np.float64(0.57),
#   np.float64(0.53),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.94),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.56),
#   np.float64(0.64),
#   np.float64(0.74),
#   np.float64(0.98),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.78),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(0.98),
#   np.float64(0.52),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.85),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.86),
#   np.float64(1.0),
#   np.float64(0.56),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(0.65),
#   np.float64(0.96),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.71),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(0.95),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.68),
#   np.float64(0.62),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.8),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.98),
#   np.float64(0.55),
#   np.float64(0.53),
#   np.float64(0.95),
#   np.float64(0.75),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(0.53),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.92),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.96),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.68),
#   np.float64(0.9),
#   np.float64(0.81),
#   np.float64(0.78),
#   np.float64(0.63),
#   np.float64(0.9),
#   np.float64(0.86),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.97),
#   np.float64(0.93),
#   np.float64(0.71),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.86),
#   np.float64(0.67),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.61),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.66),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.61),
#   np.float64(0.64),
#   np.float64(0.99),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.87),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.7),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.63),
#   np.float64(0.97),
#   np.float64(0.6),
#   np.float64(1.0),
#   np.float64(0.54),
#   np.float64(0.57),
#   np.float64(0.57),
#   np.float64(0.54),
#   np.float64(0.86),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.88),
#   np.float64(0.65),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(0.92),
#   np.float64(0.97),
#   np.float64(0.66),
#   np.float64(0.96),
#   np.float64(0.78),
#   np.float64(0.89),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.69),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.94),
#   np.float64(0.8),
#   np.float64(0.75),
#   np.float64(0.93),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(0.61),
#   np.float64(0.64),
#   np.float64(1.0),
#   np.float64(0.61),
#   np.float64(0.95),
#   np.float64(0.97),
#   np.float64(0.9),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.62),
#   np.float64(1.0),
#   np.float64(0.72),
#   np.float64(0.63),
#   np.float64(0.57),
#   np.float64(0.75),
#   np.float64(1.0),
#   np.float64(0.68),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.58),
#   np.float64(0.65),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.7),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.84),
#   np.float64(0.93),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(0.8),
#   np.float64(0.71),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(0.58),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.89),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.58),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.52),
#   np.float64(1.0),
#   np.float64(0.77),
#   np.float64(0.76),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(1.0),
#   np.float64(0.78),
#   np.float64(0.79),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.59),
#   np.float64(0.63),
#   np.float64(0.84),
#   np.float64(1.0),
#   np.float64(0.73),
#   np.float64(1.0),
#   np.float64(0.95),
#   np.float64(0.97),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(0.76),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.58),
#   np.float64(0.96),
#   np.float64(0.73),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.7),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.67),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.57),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.67),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(0.96),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.99),
#   np.float64(0.99),
#   np.float64(0.98),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.96),
#   np.float64(0.89),
#   np.float64(0.86),
#   np.float64(0.97),
#   np.float64(0.6),
#   np.float64(0.7),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.53),
#   np.float64(0.7),
#   np.float64(0.61),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.52),
#   np.float64(0.59),
#   np.float64(0.75),
#   np.float64(0.58),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.9),
#   np.float64(0.59),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.7),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(0.64),
#   np.float64(0.98),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.98),
#   np.float64(0.99),
#   np.float64(0.96),
#   np.float64(0.83),
#   np.float64(1.0),
#   np.float64(0.91),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.97),
#   np.float64(0.8),
#   np.float64(0.55),
#   np.float64(0.94),
#   np.float64(0.93),
#   np.float64(0.95),
#   np.float64(0.88),
#   np.float64(0.94),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.71),
#   np.float64(0.73),
#   np.float64(0.8),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.66),
#   np.float64(0.97),
#   np.float64(0.58),
#   np.float64(1.0),
#   np.float64(0.81),
#   np.float64(0.95),
#   np.float64(1.0),
#   np.float64(0.88),
#   np.float64(0.97),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.81),
#   np.float64(0.9),
#   np.float64(0.67),
#   np.float64(1.0),
#   np.float64(0.58),
#   np.float64(0.96),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.92),
#   np.float64(1.0),
#   np.float64(1.0),
#   np.float64(0.94),
#   np.float64(0.64),
#   np.float64(0.58),
#   np.float64(1.0),
#   ...])

# %%
mas = np.random.random_integers(1, 25, 20)
print(mas)
mas[np.argsort(mas)[-10:][::-1]]
# Out:
# [19 23 16 10 25 23 15 12 23  2  1  6  1  3 12 22 12  6  3 24]
# C:\Users\alt\AppData\Local\Temp\ipykernel_24108\2053135334.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 25 + 1) instead
#   mas = np.random.random_integers(1, 25, 20)
# array([25, 24, 23, 23, 23, 22, 19, 16, 15, 12], dtype=int32)

# %%
map_10 = 0

test_predictions = []
test_actual = []
    
for u in range(test_data.shape[0]):
    progress_bar(u, test_data.shape[0])
    for i in range(test_data.shape[1]):
        if test_data[u, i] > 0:
            pred = als_model.predict(u, i)
            test_predictions.append(pred)
            test_actual.append(test_data[u, i])

    test_predictions = np.array(test_predictions)
    test_actual = np.array(test_actual)
    if len(test_actual) != 0:
        map_10 += new_metric(test_predictions, test_actual)
    test_predictions = []
    test_actual = []
        # break

map_10 /= len(users_with_views)
map_10

# test_actual, test_predictions
# Out:
# Progress: [================================================> ] 99%	1306/1307
# np.float64(0.5437422474548451)

# %%
def new_metric_1(recommended_list, watched_list):
    rec = np.array(recommended_list)
    wat = np.array(watched_list)
    inter = np.intersect1d(rec, wat)
    return len(inter) / len(wat)

def predict(user, als_model, test_data):
    test_predictions = []
    test_actual = []
    for i in range(test_data.shape[1]):
        pred = als_model.predict(user, i)
        test_predictions.append(pred)
        if test_data[user, i] > 0:
            test_actual.append(i)
    test_predictions = np.array(test_predictions)
    test_actual = np.array(test_actual)
    indices = np.argsort(test_predictions)[-20:][::-1]
    return indices, test_actual

# %%
test_predictions = []
test_actual = []
    
for u in range(test_data.shape[0]):
    progress_bar(u, test_data.shape[0])
    indices, test_actual = predict(u, als_model, test_data)
    if len(test_actual) > 0:
        print()
        map_10 += new_metric_1(indices, test_actual)
        print("Предсказанное")
        print(df_items[df_items['item_id'].isin(indices)][['title','genres_parsed']])
        # print()
        print("Тестовые данные ")
        print(df_items[df_items['item_id'].isin(test_actual)][['title','genres_parsed']])
        # print(df_users.iloc[u]['user_id'])
        # print(u)
        # print(df_interactions_train[df_interactions_train['user_id'] == df_users.iloc[u]['user_id']])
        print("Тренировочные  данные ")
        uu = list(df_interactions_train[df_interactions_train['user_id'] == users_with_views[u]]['item_id'])
        print(df_items[df_items['item_id'].isin(uu)][['title','genres_parsed']])

        break

map_10 /= len(users_with_views)
map_10
# Out:
# Progress: [>                                                 ] 0%	0/1307
# Предсказанное
#                                                    title  \
# 393               The Adventures of the Steam Locomotive
# 744                                    Casanova Earrings
# 1249                                  The Transformation
# 1702                                   The Walking Ghost
# 1796                                              Anyuta
# 2688                  Favorite Female Mechanic Gavrilova
# 4610                                                Rave
# 7014                                           Reference
# 7364                                     Captain Koblick
# 9136         In wine reflection (with Russian subtitles)
# 10023         The Secrets of the Noble Maidens Institute
# 10143  The Brothers Bears: The Mystery of the Three W...
# 10149                                            Arrival
# 12614                                     Almost Married
# 12740                          Spartacus: Blood and Sand
# 12927                                  The Irony of Love
# 13252                  Fat burning in 15 minutes per day
# 13475                                           Hercules
# 15183                                The Gateway to Hell
# 15774                               The Provincial Woman
#
#                                            genres_parsed
# 393                           [entertainment,  cartoons]
# 744                               [russian,  melodramas]
# 1249      [science fiction,  foreign,  drama,  thriller]
# 1702                           [drama,  foreign,  crime]
# 1796                     [dramas,  soviet films,  plays]
# 2688                   [melodramas,  russian,  comedies]
# 4610                  [drama,  musical,  crime,  comedy]
# 7014                                        [melodramas]
# 7364                [drama,  foreign,  thriller,  crime]
# 9136                          [drama,  russian,  comedy]
# 10023                        [drama,  history,  russian]
# 10143       [foreign,  full-length,  adventure,  comedy]
# 10149   [drama,  science fiction,  thriller,  detective]
# 12614                            [melodramas,  comedies]
# 12740  [history,  biography,  adventure,  drama,  mel...
# 12927                            [melodramas,  comedies]
# 13252                                          [fitness]
# 13475           [action,  foreign,  fantasy,  adventure]
# 15183                          [popular science fiction]
# 15774                         [drama,  foreign,  comedy]
# Тестовые данные
#                            title           genres_parsed
# 744            Casanova Earrings  [russian,  melodramas]
# 15812  [4K] Pack Ice. The Arctic           [documentary]
# Тренировочные  данные
#                         title                 genres_parsed
# 10604             Themis sees  [drama,  detective,  comedy]
# 13544      The Werewolf Trail                  [detectives]
# 13693  Devyatayev - TV series     [drama,  war,  adventure]
# np.float64(0.0007985786132018707)
